# %% [markdown]
# # **1. Introduction to Matplotlib**
#
# **Matplotlib** is a Python library that allows you to create static, animated, and interactive visualizations. Matlab aur Excel ki tarah, lekin Python mein aur bohot zyada customizable.
#
# Matplotlib has two main APIs (ways to make plots):
#
# **A. Pyplot API**
#
# pyplot is like a simple interface to make plots quickly.
#
# You usually import it as:

# %%
#!pip install matplot
#!pip install seaborn

import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [1,2,3,4,5]
y = [10,20,25,30,40]

plt.plot(x,y)
plt.title("Simple Line plot")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %% [markdown]
# `plt.plot` se hum line plot bana sakte hain. `plt.show()` se figure screen pe aa jata hai.

# %% [markdown]
# **B. Object-Oriented (OO) API**
#
# - OO API gives more flexibility and control over the plot.
#
# - Instead of using plt, you create figure and axes objects.

# %%
#create figure axes 
fig, ax = plt.subplots()  # Create figure and axes
ax.plot(x, y)
ax.set_title("Line Plot with OO API")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
plt.show()

# %% [markdown]
# Yahaan **ax** object se hum plot ke har ek part ko individually control kar sakte hain.

# %% [markdown]
# #### **1. Axes**
#
# Axes is the part of the figure where the actual data is plotted (lines, bars, points, etc.).
#
# A Figure can have one or more Axes, and each Axes can have its own title, labels, and plots.
#
# Think of Figure as a canvas and Axes as the area on that canvas where you draw.
#
# Example:

# %%
fig = plt.figure()      # Create a canvas
ax = fig.add_axes([0, 0, 0.5, 0.5])  # Add axes: [left, bottom, width, height]
ax.plot([1, 2, 3], [4, 5, 6])
ax.set_title("Axes Example")
plt.show()

# %% [markdown]
# **2. Subplot**<br>
# Subplot is a way to divide the figure into multiple smaller axes in a grid format.
#
# Useful when you want multiple plots in a single figure.
#
# Syntax:
# > plt.subplot(rows, columns, index)

# %%
fig = plt.figure()     # Create a canvas
ax1 = fig.add_axes([0, 0, 1, 1])  # Main axes
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("First Plot")
plt.subplot(1,2,2)
plt.plot(['A','B','C'],[4,1,6])
plt.title("Second Plot")

plt.show()

# %% [markdown]
# ### **How save the image ?**

# %%
fig = plt.figure()     # Create a canvas
ax1 = fig.add_axes([0, 0, 1, 1])  # Main axes
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("First Plot")
plt.subplot(1,2,2)
plt.plot(['A','B','C'],[4,1,6])
plt.title("Second Plot")

#Save image 
plt.savefig("image.png")
plt.show()

# %% [markdown]
# #### Markers <br>
#  In Matplotlib markers are used to highlight individual
# data points on a plot.

# %%
x = [22,3,2,6,4,44,6,43,56,45,64]
y = [34,3,23,43,23,45,54,23,42,53,2]
plt.scatter(x,y,marker='p')

plt.title("Scatter Plot")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %% [markdown]
# **Matplotlib - Styles** : <br>
# In Matplotlib library styles are configurations that allow
# us to change the visual appearance of our plots easily

# %%
plt.style.use("ggplot")
x = [22,3,2,6,4,44,6,43,56,45,64]
y = [34,3,23,43,23,45,54,23,42,53,2]
plt.scatter(x,y,marker='p')

plt.title("Scatter Plot")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
import numpy as np
x = np.linspace(0 , 2*np.pi , 100)
y = np.sin(x)

fig, ax = plt.subplots(figsize = (7,4))

ax.grid(True)

ax.set_title("Basic plot with grid")

plt.xlim(1,5)

plt.plot(x,y)
plt.show()

# %% [markdown]
# **Matplotlib- Ticks and Tick Labels** <br>
# In the context of graphs and plotting, ticks are the
# small lines that show the scale of x and y-axes,
# providing a clear representation of the value
# associated with each tick.

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)


plt.plot(x,y)
plt.title("Sine wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")




plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# H:\Temp\ipykernel_11972\4126072665.py:12: SyntaxWarning: invalid escape sequence '\p'
#   custom_ticks_labels = ['0', '$\pi/2$','0', '$\pi/2$', '$\pi/2$' ]
# H:\Temp\ipykernel_11972\4126072665.py:12: SyntaxWarning: invalid escape sequence '\p'
#   custom_ticks_labels = ['0', '$\pi/2$','0', '$\pi/2$', '$\pi/2$' ]
# H:\Temp\ipykernel_11972\4126072665.py:12: SyntaxWarning: invalid escape sequence '\p'
#   custom_ticks_labels = ['0', '$\pi/2$','0', '$\pi/2$', '$\pi/2$' ]

# %%
# Bar chart 
import pandas as pd
df = pd.DataFrame(
    {
        "class" : ['ai','ml','ds','dl'],
        "member" : [30,43,22,43]
    }
)
print(df)
sns.barplot(x='class',y='member',data=df)
plt.show()
# Out:
#   class  member
# 0    ai      30
# 1    ml      43
# 2    ds      22
# 3    dl      43

# %% [markdown]
# **Line Plot**
#
# Use when: Data changes over time or epochs AI use: Training loss, accuracy curves

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [5,4,3,2,1]
plt.plot(x, y)
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# **Scatter Plot**
#
# Use when: Relationship between two variables AI use: Correlation, regression

# %%
sns.scatterplot(x='class',y='member',data=df)
# Out:
# <Axes: xlabel='class', ylabel='member'>

# %% [markdown]
# **Histogram**
#
# Use when: Checking data distribution AI use: Feature analysis

# %%
data = np.random.randn(1000)
plt.hist(data , bins =20)
plt.title("Feature Distribution")
plt.show()

# %% [markdown]
# **Box plot**<br>
# Use when: Detecting outliers AI use: Feature cleaning

# %%
age = [40,20,35,40,80,150]
plt.boxplot(age)
plt.title("Box plot example")
plt.show()

# %% [markdown]
# **Pie Chart** <br>
# **Use when:** Showing parts of a whole AI use: Dataset balance

# %%
labels = ["Train","validation","Test"]
sizes = [70,20,10]
plt.pie(sizes,labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Dataset Split")
plt.show()

# %% [markdown]
# **Violin Plot**
#
# Use when: Distribution + density AI use: Error distribution

# %%
plt.violinplot(age)
plt.title("Error Distribution")
plt.show()

# %% [markdown]
# **Stem Plot**<br>
# **Use when** :  Discrete data

# %%
plt.stem(x,y)
plt.title("Stem olot")
plt.show()

# %% [markdown]
# **Stack plot** <br>
# **Use When** : Cumulative Data

# %%
plt.stackplot(x,y)
plt.title("Stack plot example ")
plt.show()

# %% [markdown]
# ## **3D Plot (Advanced AI)**

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter([1,2,3,4,5,6], [4,5,6,4,3,5], [7,8,9,2,3,5])
plt.show()

# %% [markdown]
# **Markers & Styles**

# %%
plt.plot(x,y, linestyle='--', marker='o', color='b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Matplotlib- Legends** <br>
# It is a box containing a symbol and a label for each
# series in the graph

# %%
plt.plot(x,y, label='Loss')
plt.legend()
plt.show()
